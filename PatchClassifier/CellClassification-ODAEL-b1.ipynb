# %% [markdown]
# # Classification experiment of single (cutted) cells

# %%
# %reload_ext autoreload
# %autoreload 2
from fastai import *
from fastai.vision import *
path = Path('./')

# %%
bs=16
data = ImageDataBunch.from_folder(Path('./Data_CMC_ODAEL1/'),
        ds_tfms=get_transforms(), valid_pct=0.2, size=128, train='train', num_workers=4, bs=bs, test="test").normalize()

data.show_batch(rows=4)

# %%
data_test = (ImageList.from_folder(Path('./Data_CMC_ODAEL1/'))
        .split_by_folder(train='train', valid='test')
        .label_from_folder()).databunch().normalize()

# %%
from fastai.callbacks import SaveModelCallback
learn = cnn_learner(data, models.resnet18, metrics=accuracy, callback_fns=[ShowGraph])
osc = callbacks.OverSamplingCallback(learn)
learn.callbacks.append(osc)
learn.callbacks.append(SaveModelCallback(learn, every='improvement'))

lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='2722', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       3.12% [85/2722 00:03<01:56 3.1573]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1,1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.580525</td>
#       <td>0.607701</td>
#       <td>0.677734</td>
#       <td>01:39</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.6077013611793518.

# %% [markdown]
# Unfreeze backbone of model, train for 3 cycles of 10 epochs each

# %%
learn.unfreeze()
learn.fit_one_cycle(10, slice(1e-4,1e-3), pct_start=0.05)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.445155</td>
#       <td>0.378487</td>
#       <td>0.811199</td>
#       <td>01:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.382699</td>
#       <td>0.413963</td>
#       <td>0.791041</td>
#       <td>01:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.362038</td>
#       <td>0.361340</td>
#       <td>0.842292</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.316753</td>
#       <td>0.433817</td>
#       <td>0.785771</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.295568</td>
#       <td>0.390904</td>
#       <td>0.810804</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.266453</td>
#       <td>0.310756</td>
#       <td>0.863636</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.270323</td>
#       <td>0.309043</td>
#       <td>0.865086</td>
#       <td>01:57</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.246709</td>
#       <td>0.300300</td>
#       <td>0.870092</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.247744</td>
#       <td>0.312843</td>
#       <td>0.861001</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.233345</td>
#       <td>0.302701</td>
#       <td>0.864822</td>
#       <td>01:56</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.37848713994026184.
# Better model found at epoch 2 with valid_loss value: 0.36134010553359985.
# Better model found at epoch 5 with valid_loss value: 0.31075647473335266.
# Better model found at epoch 6 with valid_loss value: 0.3090430498123169.
# Better model found at epoch 7 with valid_loss value: 0.30030009150505066.

# %%
learn.data = data_test
#learn.validate(data.test_dl)
interp = ClassificationInterpretation.from_learner(learn, ds_type=DatasetType.Valid)
losses,idxs = interp.top_losses()

# %%
len(data.test_ds)==len(losses)==len(idxs)
interp.plot_top_losses(9, figsize=(15,11), heatmap=False)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ## Print confusion matrix, LaTeX style

# %%
print(" \\\\\n".join([" & ".join(map(str,line)) for line in interp.confusion_matrix()]))
# Out:
# 2773 & 687 \\
# 995 & 7877

# %% [markdown]
# ## Find out test accuracy

# %%
c = interp.confusion_matrix()
accuracy = np.sum(c*np.eye(2))/np.sum(c)
print('Test accuracy: ',accuracy)
# Out:
# Test accuracy:  0.8636068764190723

# %%
learn.save('CellClassifier_128px_ODAEL_b1.pth')
learn.export('CellClassifier_128px_ODAEL_b1.pth')
