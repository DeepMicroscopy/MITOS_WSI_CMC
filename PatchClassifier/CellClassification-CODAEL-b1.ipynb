# %% [markdown]
# # Classification experiment of single (cutted) cells

# %%
# %reload_ext autoreload
# %autoreload 2
from fastai import *
from fastai.vision import *
path = Path('./')

# %%
bs=16
data = ImageDataBunch.from_folder(Path('./Data_CMC_CODAEL1/'),
        ds_tfms=get_transforms(), valid_pct=0.2, size=128, train='train', num_workers=4, bs=bs, test="test").normalize()

data.show_batch(rows=4)

# %%
data_test = (ImageList.from_folder(Path('./Data_CMC_CODAEL1/'))
        .split_by_folder(train='train', valid='test')
        .label_from_folder()).databunch().normalize()

# %%
from fastai.callbacks import SaveModelCallback
learn = cnn_learner(data, models.resnet18, metrics=accuracy, callback_fns=[ShowGraph])
osc = callbacks.OverSamplingCallback(learn)
learn.callbacks.append(osc)
learn.callbacks.append(SaveModelCallback(learn, every='improvement'))

lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='2733', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       3.04% [83/2733 00:02<01:12 2.5726]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1,1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.557600</td>
#       <td>0.559390</td>
#       <td>0.715415</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.559389591217041.

# %% [markdown]
# Unfreeze backbone of model, train for 3 cycles of 10 epochs each

# %%
learn.unfreeze()
learn.fit_one_cycle(10, slice(1e-4,1e-3), pct_start=0.05)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.421434</td>
#       <td>0.389691</td>
#       <td>0.829908</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.362164</td>
#       <td>0.422870</td>
#       <td>0.798155</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.344996</td>
#       <td>0.422589</td>
#       <td>0.797628</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.269554</td>
#       <td>0.342472</td>
#       <td>0.851647</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.275075</td>
#       <td>0.354134</td>
#       <td>0.832543</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.293071</td>
#       <td>0.358813</td>
#       <td>0.831357</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.225115</td>
#       <td>0.336513</td>
#       <td>0.844532</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.233010</td>
#       <td>0.312892</td>
#       <td>0.854809</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.196182</td>
#       <td>0.321036</td>
#       <td>0.854018</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.191942</td>
#       <td>0.337259</td>
#       <td>0.848090</td>
#       <td>01:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3896910846233368.
# Better model found at epoch 3 with valid_loss value: 0.34247198700904846.
# Better model found at epoch 6 with valid_loss value: 0.3365129828453064.
# Better model found at epoch 7 with valid_loss value: 0.312892347574234.

# %%
learn.data = data_test
#learn.validate(data.test_dl)
interp = ClassificationInterpretation.from_learner(learn, ds_type=DatasetType.Valid)
losses,idxs = interp.top_losses()

# %%
len(data.test_ds)==len(losses)==len(idxs)
interp.plot_top_losses(9, figsize=(15,11), heatmap=False)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ## Print confusion matrix, LaTeX style

# %%
print(" \\\\\n".join([" & ".join(map(str,line)) for line in interp.confusion_matrix()]))
# Out:
# 2574 & 868 \\
# 676 & 8214

# %% [markdown]
# ## Find out test accuracy

# %%
c = interp.confusion_matrix()
accuracy = np.sum(c*np.eye(2))/np.sum(c)
print('Test accuracy: ',accuracy)
# Out:
# Test accuracy:  0.8747972753811223

# %%
learn.save('CellClassifier_128px_CODAEL_b1.pth')
learn.export('CellClassifier_128px_CODAEL_b1.pth')
